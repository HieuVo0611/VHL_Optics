# %% [markdown]
# # COVER

# %%
import os
import numpy as np
from PIL import Image, ImageDraw
from scipy.ndimage import label, find_objects
from collections import Counter

def find_color_blocks(image, margin=10):
    """
    Identifies all bounding boxes of color blocks in the image.
    Arguments:
    - image: PIL Image object
    - margin: Extra margin around the detected color block
    Returns:
    - List of bounding boxes (x_min, y_min, x_max, y_max)
    """
    img = image.convert("RGB")
    img_data = np.array(img)
    width, height = img.size

    # Define color threshold (greenish range)
    min_r, max_r, min_g, max_g, min_b, max_b = 0, 255, 100, 255, 100, 255
    mask = (
        (img_data[:, :, 0] >= min_r) & (img_data[:, :, 0] <= max_r) &
        (img_data[:, :, 1] >= min_g) & (img_data[:, :, 1] <= max_g) &
        (img_data[:, :, 2] >= min_b) & (img_data[:, :, 2] <= max_b)
    )

    # Find connected components
    from scipy.ndimage import label, find_objects
    labeled, num_features = label(mask)
    slices = find_objects(labeled)

    bounding_boxes = []
    for s in slices:
        x_min, x_max = s[1].start, s[1].stop
        y_min, y_max = s[0].start, s[0].stop
        bounding_boxes.append((x_min, y_min, x_max, y_max))

    return bounding_boxes

def find_closest_to_center(image, bounding_boxes):
    """
    Finds the bounding box closest to the center of the image.
    Arguments:
    - image: PIL Image object
    - bounding_boxes: List of bounding boxes (x_min, y_min, x_max, y_max)
    Returns:
    - Closest bounding box to the center
    """
    width, height = image.size
    center_x, center_y = width // 2, height // 2

    def distance_to_center(box):
        x_min, y_min, x_max, y_max = box
        box_center_x = (x_min + x_max) // 2
        box_center_y = (y_min + y_max) // 2
        return ((box_center_x - center_x) ** 2 + (box_center_y - center_y) ** 2) ** 0.5

    closest_box = min(bounding_boxes, key=distance_to_center)
    return closest_box

def analyze_common_size(bounding_boxes):
    """
    Phân tích kích thước phổ biến nhất của các bounding box.
    Arguments:
    - bounding_boxes: List các bounding box (x_min, y_min, x_max, y_max)
    Returns:
    - Kích thước phổ biến nhất (width, height)
    """
    sizes = [(x_max - x_min, y_max - y_min) for x_min, y_min, x_max, y_max in bounding_boxes]
    size_counts = Counter(sizes)
    most_common_size = size_counts.most_common(1)[0][0]  # Lấy kích thước phổ biến nhất
    return most_common_size

def adjust_to_common_size_with_fixed_right(box, common_size):
    """
    Điều chỉnh bounding box về kích thước phổ biến, giữ nguyên cạnh bên phải.
    Arguments:
    - box: Bounding box hiện tại (x_min, y_min, x_max, y_max)
    - common_size: Kích thước phổ biến (width, height)
    Returns:
    - Bounding box đã điều chỉnh
    """
    x_min, y_min, x_max, y_max = box
    current_width = x_max - x_min
    current_height = y_max - y_min
    target_width, target_height = common_size

    # Điều chỉnh cạnh trái và cạnh trên sao cho kích thước khớp
    new_x_min = max(0, x_max - target_width)  # Giữ nguyên cạnh phải, thay đổi cạnh trái
    new_y_min = max(0, y_min)  # Cạnh trên cố định
    new_y_max = new_y_min + target_height  # Điều chỉnh cạnh dưới

    return new_x_min, new_y_min, x_max, new_y_max

def process_images_with_adjusted_closest_box(input_folder, output_folder, resize_size=(256, 256)):
    """
    Process all images, tìm kích thước phổ biến nhất của closest_box
    và tinh chỉnh bounding box gần trung tâm về kích thước đó.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    all_closest_boxes = []

    # Bước 1: Thu thập tất cả closest_box từ các ảnh
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
            input_path = os.path.join(input_folder, filename)
            image = Image.open(input_path)
            bounding_boxes = find_color_blocks(image)
            if bounding_boxes:
                closest_box = find_closest_to_center(image, bounding_boxes)
                all_closest_boxes.append(closest_box)

    # Bước 2: Xác định kích thước phổ biến nhất của closest_box
    if not all_closest_boxes:
        print("Không tìm thấy bounding box nào.")
        return
    common_size = analyze_common_size(all_closest_boxes)
    print(f"Kích thước phổ biến nhất của closest_box: {common_size}")

    # Bước 3: Tinh chỉnh closest_box theo kích thước phổ biến
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
            input_path = os.path.join(input_folder, filename)
            image = Image.open(input_path)

            bounding_boxes = find_color_blocks(image)
            if bounding_boxes:
                closest_box = find_closest_to_center(image, bounding_boxes)

                # Điều chỉnh closest_box về kích thước phổ biến
                adjusted_closest_box = adjust_to_common_size_with_fixed_right(closest_box, common_size)

                # Vẽ và lưu ảnh kết quả
                cropped_image = image.crop(adjusted_closest_box)

                # Resize ảnh đã cắt thành 256x256
                resized_image = cropped_image.resize(resize_size)

                # Lưu ảnh kết quả
                output_path = os.path.join(output_folder, filename)
                resized_image.save(output_path)
                print(f"Processed and saved: {output_path}")
            else:
                print(f"No color block found in: {filename}")

# Example usage:
input_folder = './temp/'  # Replace with the path to your input folder
output_folder = './NO2/'  # Replace with the path to your output folder
process_images_with_adjusted_closest_box(input_folder, output_folder)
# Out:
# Kích thước phổ biến nhất của closest_box: (635, 659)
# Processed and saved: ./NO2/0sv9g_ngochanpham274@gmail.com_2024-11-29 11_27_21_NO2_0.25ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/15Ukv_ngochanpham274@gmail.com_2024-11-29 11_38_20_NO2_0.9ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/2d7cQ_ngochanpham274@gmail.com_2024-11-29 11_34_05_NO2_0.6ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/2En27_ngochanpham274@gmail.com_2024-11-29 11_56_24_NO2_9ppm_001_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/314Lk_ngochanpham274@gmail.com_2024-11-29 11_03_36_NO2_0.025ppm_002_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/37F7I_ngochanpham274@gmail.com_2024-11-29 11_28_50_NO2_0.4ppm_001_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/3p8Kr_ngochanpham274@gmail.com_2024-11-29 11_12_03_NO2_0.06ppm_003_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/4JypM_ngochanpham274@gmail.com_2024-11-29 11_36_41_NO2_0.8ppm_001_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/5lWN0_ngochanpham274@gmail.com_2024-11-29 11_50_32_NO2_6ppm_002_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/7iwD8_ngochanpham274@gmail.com_2024-11-29 11_36_52_NO2_0.8ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/8fMS2_ngochanpham274@gmail.com_2024-11-29 11_18_48_NO2_0.08ppm_003_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/9cjV6_ngochanpham274@gmail.com_2024-11-29 11_43_11_NO2_1ppm_002_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/9knO0_ngochanpham274@gmail.com_2024-11-29 11_31_26_NO2_0.5ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/Azzis_ngochanpham274@gmail.com_2024-11-29 11_22_17_NO2_0.1ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/caQb5_ngochanpham274@gmail.com_2024-11-29 11_49_45_NO2_5ppm_001_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/CUnUz_ngochanpham274@gmail.com_2024-11-29 11_07_43_NO2_0.05ppm_001_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/dCEIG_ngochanpham274@gmail.com_2024-11-29 11_32_23_NO2_0.6ppm_001_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/DF7mc_ngochanpham274@gmail.com_2024-11-29 11_30_01_NO2_0.4ppm_003_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/dqrEz_ngochanpham274@gmail.com_2024-11-29 11_47_18_NO2_2.5ppm_002_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/dXAYA_ngochanpham274@gmail.com_2024-11-29 11_17_47_NO2_0.08ppm_001_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/e0DNq_ngochanpham274@gmail.com_2024-11-29 11_38_22_NO2_0.9ppm_001_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/E66AS_ngochanpham274@gmail.com_2024-11-29 10_58_44_NO2_0.01ppm_001_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/EGHjj_ngochanpham274@gmail.com_2024-11-29 11_23_51_NO2_0.2ppm_001_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/ElTNq_ngochanpham274@gmail.com_2024-11-29 11_52_36_NO2_6ppm_003_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/Erroj_ngochanpham274@gmail.com_2024-11-29 11_57_54_NO2_10ppm_002_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/EyZ3A_ngochanpham274@gmail.com_2024-11-29 11_20_17_NO2_0.09ppm_001_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/fcniX_ngochanpham274@gmail.com_2024-11-29 11_50_12_NO2_6ppm_001_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/FJlI7_ngochanpham274@gmail.com_2024-11-29 11_29_20_NO2_0.4ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/fluNA_ngochanpham274@gmail.com_2024-11-29 11_07_57_NO2_0.05ppm_002_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/Fwsjt_ngochanpham274@gmail.com_2024-11-29 11_05_06_NO2_0.04ppm_001_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/g633l_ngochanpham274@gmail.com_2024-11-29 11_49_26_NO2_5ppm_003_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/gX94d_ngochanpham274@gmail.com_2024-11-29 11_35_57_NO2_0.75ppm_002_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/h3RPr_ngochanpham274@gmail.com_2024-11-29 11_16_11_NO2_0.075ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/HCBBd_ngochanpham274@gmail.com_2024-11-29 11_23_42_NO2_0.2ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/HFRBp_ngochanpham274@gmail.com_2024-11-29 10_59_24_NO2_0.01ppm_002_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/hPSUY_ngochanpham274@gmail.com_2024-11-29 11_58_02_NO2_10ppm_003_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/hRfCK_ngochanpham274@gmail.com_2024-11-29 11_45_44_NO2_2ppm_003_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/J0dU8_ngochanpham274@gmail.com_2024-11-29 11_48_27_NO2_4ppm_003_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/JbLgS_ngochanpham274@gmail.com_2024-11-29 11_34_12_NO2_0.6ppm_003_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/jCCOz_ngochanpham274@gmail.com_2024-11-29 11_55_26_NO2_8ppm_003_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/jJSFh_ngochanpham274@gmail.com_2024-11-29 11_43_08_NO2_1ppm_001_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/Kb8G6_ngochanpham274@gmail.com_2024-11-29 11_16_11_NO2_0.075ppm_003_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/l63R8_ngochanpham274@gmail.com_2024-11-29 11_37_29_NO2_0.8ppm_003_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/lKzAk_ngochanpham274@gmail.com_2024-11-29 11_22_36_NO2_0.1ppm_003_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/LLJ4P_ngochanpham274@gmail.com_2024-11-29 11_06_46_NO2_0.04ppm_003_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/lmETB_ngochanpham274@gmail.com_2024-11-29 11_55_24_NO2_8ppm_002_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/lwnmi_ngochanpham274@gmail.com_2024-11-29 11_56_16_NO2_9ppm_002_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/LZcQs_ngochanpham274@gmail.com_2024-11-29 11_22_31_NO2_0.1ppm_001_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/mABBS_ngochanpham274@gmail.com_2024-11-29 11_01_15_NO2_0.02ppm_002_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/mVR5f_ngochanpham274@gmail.com_2024-11-29 11_54_22_NO2_7.5ppm_002_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/n5fqq_ngochanpham274@gmail.com_2024-11-29 11_21_23_NO2_0.09ppm_003_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/NC4GF_ngochanpham274@gmail.com_2024-11-29 11_04_08_NO2_0.025ppm_003_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/nEyre_ngochanpham274@gmail.com_2024-11-29 11_57_23_NO2_10ppm_001_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/nHX7H_ngochanpham274@gmail.com_2024-11-29 11_46_50_NO2_2.5ppm_001_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/nOuj4_ngochanpham274@gmail.com_2024-11-29 11_02_54_NO2_0.025ppm_0001_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/NV2CM_ngochanpham274@gmail.com_2024-11-29 11_31_48_NO2_0.5ppm_003_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/nxNl8_ngochanpham274@gmail.com_2024-11-29 11_54_49_NO2_8ppm_001_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/oe2Xk_ngochanpham274@gmail.com_2024-11-29 11_54_24_NO2_7.5ppm_003_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/OrSrK_ngochanpham274@gmail.com_2024-11-29 11_09_52_NO2_0.06ppm_001_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/PKSZD_ngochanpham274@gmail.com_2024-11-29 10_59_40_NO2_0.01ppm_003_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/pwiVx_ngochanpham274@gmail.com_2024-11-29 11_49_15_NO2_4ppm_002_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/QfHHq_ngochanpham274@gmail.com_2024-11-29 11_00_41_NO2_0.02ppm_001_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/QkfPm_ngochanpham274@gmail.com_2024-11-29 11_30_38_NO2_0.5ppm_001_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/qPTPh_ngochanpham274@gmail.com_2024-11-29 11_53_23_NO2_7.5ppm_001_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/QVynp_ngochanpham274@gmail.com_2024-11-29 11_24_57_NO2_0.25ppm_001_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/R65jc_ngochanpham274@gmail.com_2024-11-29 11_57_13_NO2_9ppm_003_samsung test_10.8768544_106.6782314.jpg
# Processed and saved: ./NO2/SnUbf_ngochanpham274@gmail.com_2024-11-29 11_48_15_NO2_4ppm_001_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/sshD8_ngochanpham274@gmail.com_2024-11-29 11_24_14_NO2_0.2ppm_003_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/su840_ngochanpham274@gmail.com_2024-11-29 11_34_56_NO2_0.75ppm_001_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/t95dK_ngochanpham274@gmail.com_2024-11-29 11_28_21_NO2_0.25ppm_003_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/TbuFB_ngochanpham274@gmail.com_2024-11-29 11_46_44_NO2_2.5ppm_003_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/Tfnd7_ngochanpham274@gmail.com_2024-11-29 11_07_59_NO2_0.05ppm_003_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/tN5G6_ngochanpham274@gmail.com_2024-11-29 11_05_34_NO2_0.04ppm_002_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/TQIF8_ngochanpham274@gmail.com_2024-11-29 11_49_21_NO2_5ppm_002_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/trzyg_ngochanpham274@gmail.com_2024-11-29 11_13_32_NO2_0.0675ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/ubDt3_ngochanpham274@gmail.com_2024-11-29 11_35_39_NO2_0.75ppm_003_samsung test_10.876833_106.6782313.jpg
# Processed and saved: ./NO2/ucg10_ngochanpham274@gmail.com_2024-11-29 11_20_18_NO2_0.09ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/UyT7B_ngochanpham274@gmail.com_2024-11-29 11_43_41_NO2_1ppm_003_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/vimTi_ngochanpham274@gmail.com_2024-11-29 11_19_06_NO2_0.08ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/w8znC_ngochanpham274@gmail.com_2024-11-29 11_44_25_NO2_2ppm_001_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/XcGTS_ngochanpham274@gmail.com_2024-11-29 11_14_10_NO2_0.0675ppm_001_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/xxnDL_ngochanpham274@gmail.com_2024-11-29 11_46_56_NO2_2ppm_002_samsung test_10.8768361_106.6782434.jpg
# Processed and saved: ./NO2/yTfJd_ngochanpham274@gmail.com_2024-11-29 11_12_12_NO2_0.06ppm_002_samsung test_10.8768629_106.6782381.jpg
# Processed and saved: ./NO2/yz1wf_ngochanpham274@gmail.com_2024-11-29 11_01_41_NO2_0.02ppm_003_samsung test_10.8768398_106.6782302.jpg
# Processed and saved: ./NO2/Z60LV_ngochanpham274@gmail.com_2024-11-29 11_09_58_NO2_0.06ppm_002_samsung test_10.8768398_106.6782302.jpg

# %% [markdown]
# # MIDDLE

# %%
def crop_and_resize_center_square(input_folder, output_folder, resize_size=(256, 256)):
    """
    Cắt hình vuông nằm giữa ảnh, có diện tích bằng 1/3 diện tích ảnh gốc,
    sau đó resize thành 256x256 và lưu vào folder khác.
    Arguments:
    - input_folder: Thư mục chứa ảnh đã resize (256x256)
    - output_folder: Thư mục lưu ảnh kết quả
    - resize_size: Kích thước đích (width, height) cho ảnh sau khi resize
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
            input_path = os.path.join(input_folder, filename)
            image = Image.open(input_path)
            width, height = image.size

            # Xác định kích thước của hình vuông với diện tích bằng 1/3 diện tích ảnh gốc
            side_length = int((width * height / 3) ** 0.5)

            # Xác định tọa độ để hình vuông nằm giữa ảnh
            center_x, center_y = width // 2, height // 2
            x_min = max(0, center_x - side_length // 2)
            y_min = max(0, center_y - side_length // 2)
            x_max = min(width, x_min + side_length)
            y_max = min(height, y_min + side_length)

            # Cắt hình vuông ở giữa
            cropped_image = image.crop((x_min, y_min, x_max, y_max))

            # Resize hình vuông đã cắt thành 256x256
            resized_image = cropped_image.resize(resize_size)

            # Lưu ảnh kết quả
            output_path = os.path.join(output_folder, filename)
            resized_image.save(output_path)
            print(f"Processed and saved: {output_path}")

# Gọi hàm xử lý
intermediate_folder = './samsung_cover/'  # Thư mục chứa ảnh resize 256x256 ban đầu
final_folder = './samsung_middle/'       # Thư mục lưu kết quả cuối cùng
crop_and_resize_center_square(intermediate_folder, final_folder)
# Out:
# Processed and saved: ./samsung_middle/0iOM6_ngochanpham274@gmail.com_2024-11-21 12_52_30_NH3_5ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/1iVDC_ngochanpham274@gmail.com_2024-11-21 12_04_02_NH3_0,25ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/2qR82_ngochanpham274@gmail.com_2024-11-21 12_00_28_NH3_0,09ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/3iW5i_ngochanpham274@gmail.com_2024-11-21 11_48_30_NH3_0,01ppm_003_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/3IwPn_ngochanpham274@gmail.com_2024-11-21 11_59_52_NH3_0,075ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/4fkPP_ngochanpham274@gmail.com_2024-11-21 12_50_09_NH3_4ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/5RgJx_ngochanpham274@gmail.com_2024-11-21 11_55_08_NH3_0,05ppm_002_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/5ufqX_ngochanpham274@gmail.com_2024-11-21 12_47_34_NH3_1ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/6jN5i_ngochanpham274@gmail.com_2024-11-21 12_01_17_NH3_0,09ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/75RLc_ngochanpham274@gmail.com_2024-11-21 11_54_37_NH3_0,05ppm_001_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/7XsSn_ngochanpham274@gmail.com_2024-11-21 13_00_27_NH3_10ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/89K41_ngochanpham274@gmail.com_2024-11-21 11_56_45_NH3_0,06ppm_002_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/8k7cP_ngochanpham274@gmail.com_2024-11-21 11_47_33_NH3_0,01ppm_001_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/a7HIj_ngochanpham274@gmail.com_2024-11-21 11_59_08_NH3_0,075ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/afep0_ngochanpham274@gmail.com_2024-11-21 11_59_33_NH3_0,075ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/aPyVs_ngochanpham274@gmail.com_2024-11-21 12_58_12_NH3_8ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/aSt8Q_ngochanpham274@gmail.com_2024-11-21 11_55_27_NH3_0,05ppm_003_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/Beiuv_ngochanpham274@gmail.com_2024-11-21 12_02_37_NH3_0,2ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/bm4Wz_ngochanpham274@gmail.com_2024-11-21 12_48_04_NH3_1ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/CuO7V_ngochanpham274@gmail.com_2024-11-21 12_03_36_NH3_0,25ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/E340h_ngochanpham274@gmail.com_2024-11-21 12_47_03_NH3_1ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/ffjYf_ngochanpham274@gmail.com_2024-11-21 12_38_01_NH3_0,6ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/g8YQk_ngochanpham274@gmail.com_2024-11-21 12_44_30_NH3_0,75ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/gfpbF_ngochanpham274@gmail.com_2024-11-21 11_53_47_NH3_0,04ppm_003_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/guVRF_ngochanpham274@gmail.com_2024-11-21 12_04_42_NH3_0,4ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/h2Uz1_ngochanpham274@gmail.com_2024-11-21 12_56_28_NH3_7,5ppm_002___.jpg
# Processed and saved: ./samsung_middle/KAGc0_ngochanpham274@gmail.com_2024-11-21 12_00_57_NH3_0,09ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/KCDt0_ngochanpham274@gmail.com_2024-11-21 12_01_52_NH3_0,2ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/KGJIU_ngochanpham274@gmail.com_2024-11-21 12_56_05_NH3_7,5ppm_001___.jpg
# Processed and saved: ./samsung_middle/l4ubk_ngochanpham274@gmail.com_2024-11-21 12_54_53_NH3_6ppm_002___.jpg
# Processed and saved: ./samsung_middle/Lvewy_ngochanpham274@gmail.com_2024-11-21 11_52_09_NH3_0,025ppm_003_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/m1cIl_ngochanpham274@gmail.com_2024-11-21 11_48_07_NH3_0,01ppm_002_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/m5U9e_ngochanpham274@gmail.com_2024-11-21 11_51_24_NH3_0,025ppm_001_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/mfKfm_ngochanpham274@gmail.com_2024-11-21 12_51_00_NH3_4ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/n5Ffa_ngochanpham274@gmail.com_2024-11-21 11_50_21_NH3_0,02ppm_003_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/nLnhx_ngochanpham274@gmail.com_2024-11-21 12_48_41_NH3_2ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/nucal_ngochanpham274@gmail.com_2024-11-21 12_45_51_NH3_0,8ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/PWJIt_ngochanpham274@gmail.com_2024-11-21 12_02_16_NH3_0,2ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/QbYCt_ngochanpham274@gmail.com_2024-11-21 12_52_09_NH3_5ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/Qe5iL_ngochanpham274@gmail.com_2024-11-21 12_49_00_NH3_2ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/qzuvv_ngochanpham274@gmail.com_2024-11-21 12_58_48_NH3_8ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/RJ5m1_ngochanpham274@gmail.com_2024-11-21 12_05_07_NH3_0,4ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/RztkA_ngochanpham274@gmail.com_2024-11-21 12_57_05_NH3_7,5ppm_003___.jpg
# Processed and saved: ./samsung_middle/S5UFV_ngochanpham274@gmail.com_2024-11-21 12_45_31_NH3_0,8ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/SBY8O_ngochanpham274@gmail.com_2024-11-21 12_54_27_NH3_6ppm_001___.jpg
# Processed and saved: ./samsung_middle/SNREN_ngochanpham274@gmail.com_2024-11-21 11_49_58_NH3_0,02ppm_002_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/sUpNq_ngochanpham274@gmail.com_2024-11-21 12_46_14_NH3_0,8ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/sxi1U_ngochanpham274@gmail.com_2024-11-21 12_42_43_NH3_0,75ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/tJSPL_ngochanpham274@gmail.com_2024-11-21 12_42_59_NH3_0,75ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/tp9X1_ngochanpham274@gmail.com_2024-11-21 11_53_22_NH3_0,04ppm_002_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/UOAci_ngochanpham274@gmail.com_2024-11-21 11_49_34_NH3_0,02ppm_001_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/V2wTf_ngochanpham274@gmail.com_2024-11-21 12_51_48_NH3_5ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/VGlsW_ngochanpham274@gmail.com_2024-11-21 11_58_21_NH3_0,06ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/Vxzpp_ngochanpham274@gmail.com_2024-11-21 12_49_21_NH3_2ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/welAT_ngochanpham274@gmail.com_2024-11-21 12_53_09_NH3_6ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/wgO0S_ngochanpham274@gmail.com_2024-11-21 13_00_04_NH3_10ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/woLH1_ngochanpham274@gmail.com_2024-11-21 11_52_57_NH3_0,04ppm_001_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/xVfS7_ngochanpham274@gmail.com_2024-11-21 12_05_27_NH3_0,4ppm_003_samsung test__.jpg
# Processed and saved: ./samsung_middle/yDrOS_ngochanpham274@gmail.com_2024-11-21 11_51_44_NH3_0,025ppm_002_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/yfodQ_ngochanpham274@gmail.com_2024-11-21 12_57_51_NH3_8ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/yvAOg_ngochanpham274@gmail.com_2024-11-21 12_39_33_NH3_0,6ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/ZaAYC_ngochanpham274@gmail.com_2024-11-21 12_03_18_NH3_0,25ppm_001_samsung test__.jpg
# Processed and saved: ./samsung_middle/zabnq_ngochanpham274@gmail.com_2024-11-21 12_55_24_NH3_6ppm_003___.jpg
# Processed and saved: ./samsung_middle/zfoUU_ngochanpham274@gmail.com_2024-11-21 11_56_16_NH3_0,06ppm_001_samsung test_10.8768228_106.6782789.jpg
# Processed and saved: ./samsung_middle/zQtpt_ngochanpham274@gmail.com_2024-11-21 12_50_29_NH3_4ppm_002_samsung test__.jpg
# Processed and saved: ./samsung_middle/ZrrcB_ngochanpham274@gmail.com_2024-11-21 12_59_42_NH3_10ppm_001_samsung test__.jpg
